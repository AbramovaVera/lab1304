# %% [markdown]
# <a href="https://colab.research.google.com/github/AbramovaVera/lab1304/blob/main/%D0%92%D0%B5%D1%80%D0%B0_01_06_%D0%BF%D0%BE%D0%B3%D0%BE%D0%BD%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
n=1000
dt=1
R=700
Vhare=5
Vdog=5.35
da=(Vhare*dt)/R
n=800
Xhare=np.zeros(n)
Yhare=np.zeros(n)
Xdog=np.zeros(n)
Ydog=np.zeros(n)
f=np.zeros(n)
Xdog[0]=-R
Ydog[0]=0
for i in range(n):
    Xhare[i]=R*np.sin(da*i)
    Yhare[i]=R*np.cos(da*i)
    f[i]=np.arctan2((Yhare[i]-Ydog[i]),(Xhare[i]-Xdog[i]))
fig, ax=plt.subplots()
ax.set_xlim(-R, R)
ax.set_ylim(-R, R)
hare_line,=ax.plot([],[],'b-',label='Hare')
dog_line,=ax.plot([], [],'r-',label='Dog')
hare_point,=ax.plot([],[],'bo')
dog_point,=ax.plot([],[],'ro')
def init():
    hare_line.set_data([],[])
    dog_line.set_data([],[])
    hare_point.set_data([],[])
    dog_point.set_data([],[])
    return hare_line, dog_line, hare_point, dog_point
def animate(i):
    hare_line.set_data(Xhare[:i+1],Yhare[:i+1])
    dog_line.set_data(Xdog[:i+1],Ydog[:i+1])
    hare_point.set_data(Xhare[i],Yhare[i])
    dog_point.set_data(Xdog[i],Ydog[i])
    return hare_line, dog_line, hare_point, dog_point
def update(frame):
    global Xdog, Ydog, f
    if frame<n-1:
        Xdog[frame+1]=Xdog[frame]+Vdog*dt*np.cos(f[frame])
        Ydog[frame+1]=Ydog[frame]+Vdog*dt*np.sin(f[frame])
        f[frame+1]=np.arctan2((Yhare[frame]-Ydog[frame]),(Xhare[frame]-Xdog[frame]))
        return animate(frame)
ax.legend()
ani=animation.FuncAnimation(fig, update, frames=n, interval=100, blit=True, init_func=init)
ani.save('double.mp4',fps=30,extra_args=['-vcodec','libx264'])
plt.show()
# Out:
# <ipython-input-31-91e58a07e94a>:35: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   hare_point.set_data(Xhare[i],Yhare[i])
# <ipython-input-31-91e58a07e94a>:36: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   dog_point.set_data(Xdog[i],Ydog[i])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-91e58a07e94a> in <cell line: 47>()
#      45 ax.legend()
#      46 ani=animation.FuncAnimation(fig, update, frames=n, interval=100, blit=True, init_func=init)
# ---> 47 ani.save('double.mp4',fps=30,extra_args=['-vcodec','libx264'])
#      48 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1101                 for anim, d in zip(all_anim, data):
#    1102                     # TODO: See if turning off blit is really necessary
# -> 1103                     anim._draw_next_frame(d, blit=False)
#    1104                     if progress_callback is not None:
#    1105                         progress_callback(frame_number, total_frames)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1136         # post- draw, as well as the drawing of the frame itself.
#    1137         self._pre_draw(framedata, blit)
# -> 1138         self._draw_frame(framedata)
#    1139         self._post_draw(framedata, blit)
#    1140
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1775                 iter(self._drawn_artists)
#    1776             except TypeError:
# -> 1777                 raise err from None
#    1778
#    1779             # check each item if it's artist
#
# RuntimeError: The animation function must return a sequence of Artist objects.
